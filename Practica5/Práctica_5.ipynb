# %% [markdown]
# <a href="https://colab.research.google.com/github/NohemiVargas/Procesamiento_y_clasificacion_datos/blob/main/Practica5/Pr%C3%A1ctica_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica 5. Regresión (árbol de regresión)
# Laura Nohemí Vargas de la Rosa

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error,mean_squared_error
from sklearn.tree import plot_tree
#data=pd.read_csv('/content/drive/MyDrive/Colaboratory/Procesamiento y clasificación de Datos/Práctica 4/diabetes.csv')
#data.head()

# %%
from sklearn.datasets import fetch_california_housing
california_housing = fetch_california_housing(as_frame=True)

# %%
dataset=california_housing.frame
dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
dataset = dataset.dropna()
dataset.columns
# Out:
# Index(['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup',
#        'Latitude', 'Longitude', 'MedHouseVal'],
#       dtype='object')

# %%
X = dataset.drop(["MedHouseVal"], axis=1)
y = dataset["MedHouseVal"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=44)

# %%
model = DecisionTreeRegressor(random_state=44)
model.fit(X_train, y_train)
predictions = model.predict(X_test)

print(r2_score(y_test,predictions))
print(predictions)
# Out:
# 0.6339447771666364
# [1.879 3.627 4.771 ... 1.188 2.25  3.53 ]

# %%
mae = mean_absolute_error(y_true=y_test,y_pred=predictions)
#squared True returns MSE value, False returns RMSE value.
mse = mean_squared_error(y_true=y_test,y_pred=predictions) #default=True
rmse = mean_squared_error(y_true=y_test,y_pred=predictions,squared=False)
  
print("MAE:",mae)
print("MSE:",mse)
print("RMSE:",rmse)
# Out:
# MAE: 0.45527907558139535
# MSE: 0.4933488804690504
# RMSE: 0.7023879842857866

# %%
plt.figure(figsize=(10,8), dpi=150)
plot_tree(model, feature_names=X.columns)
# Out:
# [Text(0.6465676685623226, 0.9852941176470589, 'MedInc <= 5.076\nsquared_error = 1.326\nsamples = 15480\nvalue = 2.07'),
#  Text(0.3683517635521447, 0.9558823529411765, 'MedInc <= 3.129\nsquared_error = 0.833\nsamples = 12264\nvalue = 1.741'),
#  Text(0.16853756994808955, 0.9264705882352942, 'AveRooms <= 4.311\nsquared_error = 0.576\nsamples = 6088\nvalue = 1.375'),
#  Text(0.07123025425667043, 0.8970588235294118, 'AveOccup <= 2.509\nsquared_error = 0.69\nsamples = 2527\nvalue = 1.64'),
#  Text(0.03389737451978356, 0.8676470588235294, 'Latitude <= 37.925\nsquared_error = 1.05\nsamples = 803\nvalue = 2.041'),
#  Text(0.020986563243712203, 0.8382352941176471, 'Longitude <= -118.225\nsquared_error = 1.05\nsamples = 679\nvalue = 2.192'),
#  Text(0.006581315101608997, 0.8088235294117647, 'Longitude <= -122.325\nsquared_error = 1.151\nsamples = 422\nvalue = 2.496'),
#  Text(0.0007231741986582123, 0.7794117647058824, 'AveRooms <= 2.706\nsquared_error = 1.355\nsamples = 53\nvalue = 3.359'),
#  Text(0.00020181605543950111, 0.75, 'Population <= 3889.0\nsquared_error = 0.819\nsamples = 7\nvalue = 4.393'),
#  Text(0.0001345440369596674, 0.7205882352941176, 'Latitude <= 37.785\nsquared_error = 0.063\nsamples = 6\nvalue = 4.75'),
#  Text(6.72720184798337e-05, 0.6911764705882353, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.00020181605543950111, 0.6911764705882353, 'Population <= 2454.0\nsquared_error = 0.047\nsamples = 4\nvalue = 4.625'),
#  Text(0.0001345440369596674, 0.6617647058823529, 'squared_error = 0.0\nsamples = 3\nvalue = 4.5'),
#  Text(0.0002690880739193348, 0.6617647058823529, 'squared_error = -0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.0002690880739193348, 0.7205882352941176, 'squared_error = 0.0\nsamples = 1\nvalue = 2.25'),
#  Text(0.0012445323418769235, 0.75, 'AveRooms <= 3.153\nsquared_error = 1.249\nsamples = 46\nvalue = 3.202'),
#  Text(0.0007063561940382539, 0.7205882352941176, 'AveRooms <= 3.114\nsquared_error = 0.579\nsamples = 10\nvalue = 2.038'),
#  Text(0.0005381761478386696, 0.6911764705882353, 'MedInc <= 2.174\nsquared_error = 0.383\nsamples = 8\nvalue = 2.297'),
#  Text(0.00040363211087900223, 0.6617647058823529, 'Longitude <= -122.425\nsquared_error = 0.09\nsamples = 3\nvalue = 1.55'),
#  Text(0.0003363600923991685, 0.6323529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 1.15'),
#  Text(0.0004709041293588359, 0.6323529411764706, 'Latitude <= 37.775\nsquared_error = 0.016\nsamples = 2\nvalue = 1.75'),
#  Text(0.00040363211087900223, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 1.625'),
#  Text(0.0005381761478386696, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 1.875'),
#  Text(0.000672720184798337, 0.6617647058823529, 'Population <= 611.5\nsquared_error = 0.023\nsamples = 5\nvalue = 2.746'),
#  Text(0.0006054481663185033, 0.6323529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 2.5'),
#  Text(0.0007399922032781707, 0.6323529411764706, 'Latitude <= 37.725\nsquared_error = 0.01\nsamples = 4\nvalue = 2.807'),
#  Text(0.000672720184798337, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 2.979'),
#  Text(0.0008072642217580045, 0.6029411764705882, 'squared_error = 0.0\nsamples = 3\nvalue = 2.75'),
#  Text(0.0008745362402378382, 0.6911764705882353, 'MedInc <= 2.137\nsquared_error = 0.016\nsamples = 2\nvalue = 1.0'),
#  Text(0.0008072642217580045, 0.6617647058823529, 'squared_error = 0.0\nsamples = 1\nvalue = 1.125'),
#  Text(0.0009418082587176718, 0.6617647058823529, 'squared_error = 0.0\nsamples = 1\nvalue = 0.875'),
#  Text(0.001782708489715593, 0.7205882352941176, 'HouseAge <= 25.0\nsquared_error = 0.954\nsamples = 36\nvalue = 3.525'),
#  Text(0.0012108963326370066, 0.6911764705882353, 'Population <= 1660.0\nsquared_error = 0.718\nsamples = 4\nvalue = 2.078'),
#  Text(0.0010763522956773392, 0.6617647058823529, 'AveBedrms <= 1.138\nsquared_error = 0.019\nsamples = 2\nvalue = 1.264'),
#  Text(0.0010090802771975055, 0.6323529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 1.404'),
#  Text(0.001143624314157173, 0.6323529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 1.125'),
#  Text(0.001345440369596674, 0.6617647058823529, 'MedInc <= 2.913\nsquared_error = 0.094\nsamples = 2\nvalue = 2.891'),
#  Text(0.0012781683511168403, 0.6323529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 2.584'),
#  Text(0.0014127123880765078, 0.6323529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 3.197'),
#  Text(0.0023545206467941796, 0.6911764705882353, 'AveOccup <= 2.221\nsquared_error = 0.689\nsamples = 32\nvalue = 3.706'),
#  Text(0.0018499805081954267, 0.6617647058823529, 'Latitude <= 37.785\nsquared_error = 0.481\nsamples = 22\nvalue = 3.992'),
#  Text(0.0015472564250361752, 0.6323529411764706, 'AveOccup <= 2.187\nsquared_error = 0.309\nsamples = 15\nvalue = 3.751'),
#  Text(0.0014799844065563415, 0.6029411764705882, 'Longitude <= -122.445\nsquared_error = 0.23\nsamples = 14\nvalue = 3.668'),
#  Text(0.0012781683511168403, 0.5735294117647058, 'AveOccup <= 2.077\nsquared_error = 0.219\nsamples = 2\nvalue = 4.533'),
#  Text(0.0012108963326370066, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.001345440369596674, 0.5441176470588235, 'squared_error = -0.0\nsamples = 1\nvalue = 4.065'),
#  Text(0.0016818004619958426, 0.5735294117647058, 'AveOccup <= 1.985\nsquared_error = 0.087\nsamples = 12\nvalue = 3.524'),
#  Text(0.0014799844065563415, 0.5441176470588235, 'AveOccup <= 1.918\nsquared_error = 0.071\nsamples = 6\nvalue = 3.696'),
#  Text(0.0014127123880765078, 0.5147058823529411, 'AveOccup <= 1.762\nsquared_error = 0.012\nsamples = 5\nvalue = 3.585'),
#  Text(0.0012781683511168403, 0.4852941176470588, 'AveBedrms <= 1.1\nsquared_error = 0.002\nsamples = 2\nvalue = 3.708'),
#  Text(0.0012108963326370066, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.75'),
#  Text(0.001345440369596674, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.667'),
#  Text(0.0015472564250361752, 0.4852941176470588, 'Population <= 1495.0\nsquared_error = 0.001\nsamples = 3\nvalue = 3.502'),
#  Text(0.0014799844065563415, 0.45588235294117646, 'Population <= 782.5\nsquared_error = 0.0\nsamples = 2\nvalue = 3.481'),
#  Text(0.0014127123880765078, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 3.462'),
#  Text(0.0015472564250361752, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.001614528443516009, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.545'),
#  Text(0.0015472564250361752, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 4.25'),
#  Text(0.0018836165174353436, 0.5441176470588235, 'Latitude <= 37.76\nsquared_error = 0.044\nsamples = 6\nvalue = 3.353'),
#  Text(0.0017490724804756763, 0.5147058823529411, 'AveBedrms <= 1.077\nsquared_error = 0.008\nsamples = 2\nvalue = 3.092'),
#  Text(0.0016818004619958426, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 3.184'),
#  Text(0.0018163444989555098, 0.4852941176470588, 'squared_error = -0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.002018160554395011, 0.5147058823529411, 'AveRooms <= 4.257\nsquared_error = 0.01\nsamples = 4\nvalue = 3.484'),
#  Text(0.0019508885359151773, 0.4852941176470588, 'Longitude <= -122.425\nsquared_error = 0.003\nsamples = 3\nvalue = 3.431'),
#  Text(0.0018836165174353436, 0.45588235294117646, 'AveBedrms <= 1.088\nsquared_error = 0.0\nsamples = 2\nvalue = 3.396'),
#  Text(0.0018163444989555098, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 3.375'),
#  Text(0.0019508885359151773, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 3.417'),
#  Text(0.002018160554395011, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.0020854325728748447, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 3.643'),
#  Text(0.001614528443516009, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 4.9'),
#  Text(0.0021527045913546784, 0.6323529411764706, 'AveOccup <= 2.096\nsquared_error = 0.457\nsamples = 7\nvalue = 4.508'),
#  Text(0.002018160554395011, 0.6029411764705882, 'AveRooms <= 3.267\nsquared_error = 0.028\nsamples = 5\nvalue = 4.917'),
#  Text(0.0019508885359151773, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 4.583'),
#  Text(0.0020854325728748447, 0.5735294117647058, 'Longitude <= -122.435\nsquared_error = 0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.002018160554395011, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.0021527045913546784, 0.5441176470588235, 'squared_error = -0.0\nsamples = 3\nvalue = 5.0'),
#  Text(0.002287248628314346, 0.6029411764705882, 'AveOccup <= 2.14\nsquared_error = 0.07\nsamples = 2\nvalue = 3.486'),
#  Text(0.002219976609834512, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.75'),
#  Text(0.0023545206467941796, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.222'),
#  Text(0.002859060785392932, 0.6617647058823529, 'AveBedrms <= 1.102\nsquared_error = 0.575\nsamples = 10\nvalue = 3.078'),
#  Text(0.002690880739193348, 0.6323529411764706, 'Population <= 1335.0\nsquared_error = 0.116\nsamples = 8\nvalue = 2.738'),
#  Text(0.0025563367022336807, 0.6029411764705882, 'AveRooms <= 3.623\nsquared_error = 0.002\nsamples = 2\nvalue = 3.119'),
#  Text(0.002489064683753847, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.167'),
#  Text(0.0026236087207135144, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.071'),
#  Text(0.0028254247761530155, 0.6029411764705882, 'Population <= 2604.5\nsquared_error = 0.09\nsamples = 6\nvalue = 2.611'),
#  Text(0.002758152757673182, 0.5735294117647058, 'AveOccup <= 2.326\nsquared_error = 0.057\nsamples = 5\nvalue = 2.519'),
#  Text(0.0026236087207135144, 0.5441176470588235, 'MedInc <= 2.553\nsquared_error = 0.012\nsamples = 3\nvalue = 2.344'),
#  Text(0.0025563367022336807, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.5'),
#  Text(0.002690880739193348, 0.5147058823529411, 'Longitude <= -122.475\nsquared_error = 0.0\nsamples = 2\nvalue = 2.266'),
#  Text(0.0026236087207135144, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 2.282'),
#  Text(0.002758152757673182, 0.4852941176470588, 'squared_error = -0.0\nsamples = 1\nvalue = 2.25'),
#  Text(0.0028926967946328493, 0.5441176470588235, 'HouseAge <= 47.5\nsquared_error = 0.009\nsamples = 2\nvalue = 2.782'),
#  Text(0.0028254247761530155, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.689'),
#  Text(0.002959968813112683, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.875'),
#  Text(0.0028926967946328493, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.07'),
#  Text(0.0030272408315925167, 0.6323529411764706, 'AveRooms <= 4.259\nsquared_error = 0.098\nsamples = 2\nvalue = 4.438'),
#  Text(0.002959968813112683, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 4.125'),
#  Text(0.0030945128500723504, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 4.75'),
#  Text(0.012439456004559781, 0.7794117647058824, 'Latitude <= 34.115\nsquared_error = 0.999\nsamples = 369\nvalue = 2.372'),
#  Text(0.006934864787841529, 0.75, 'Longitude <= -118.385\nsquared_error = 1.086\nsamples = 143\nvalue = 2.882'),
#  Text(0.004448362221979004, 0.7205882352941176, 'AveBedrms <= 1.068\nsquared_error = 0.586\nsamples = 42\nvalue = 3.718'),
#  Text(0.0038513230579704794, 0.6911764705882353, 'HouseAge <= 40.0\nsquared_error = 0.327\nsamples = 20\nvalue = 3.326'),
#  Text(0.0034645089517114356, 0.6617647058823529, 'AveRooms <= 2.428\nsquared_error = 0.214\nsamples = 14\nvalue = 3.089'),
#  Text(0.003397236933231602, 0.6323529411764706, 'squared_error = 0.0\nsamples = 1\nvalue = 1.844'),
#  Text(0.0035317809701912693, 0.6323529411764706, 'MedInc <= 2.565\nsquared_error = 0.102\nsamples = 13\nvalue = 3.185'),
#  Text(0.003229056887032018, 0.6029411764705882, 'AveOccup <= 1.684\nsquared_error = 0.054\nsamples = 4\nvalue = 3.439'),
#  Text(0.003161784868552184, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.1'),
#  Text(0.0032963289055118515, 0.5735294117647058, 'AveRooms <= 2.872\nsquared_error = 0.021\nsamples = 3\nvalue = 3.552'),
#  Text(0.003229056887032018, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 3.75'),
#  Text(0.0033636009239916853, 0.5441176470588235, 'Longitude <= -118.42\nsquared_error = 0.002\nsamples = 2\nvalue = 3.453'),
#  Text(0.0032963289055118515, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.003430872942471519, 0.5147058823529411, 'squared_error = -0.0\nsamples = 1\nvalue = 3.406'),
#  Text(0.003834505053350521, 0.6029411764705882, 'Population <= 966.5\nsquared_error = 0.081\nsamples = 9\nvalue = 3.072'),
#  Text(0.0036999610163908534, 0.5735294117647058, 'AveBedrms <= 1.025\nsquared_error = 0.004\nsamples = 3\nvalue = 2.786'),
#  Text(0.0036326889979110197, 0.5441176470588235, 'HouseAge <= 26.5\nsquared_error = 0.0\nsamples = 2\nvalue = 2.742'),
#  Text(0.003565416979431186, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.763'),
#  Text(0.0036999610163908534, 0.5147058823529411, 'squared_error = -0.0\nsamples = 1\nvalue = 2.72'),
#  Text(0.003767233034870687, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 2.875'),
#  Text(0.003969049090310189, 0.5735294117647058, 'AveRooms <= 3.052\nsquared_error = 0.058\nsamples = 6\nvalue = 3.215'),
#  Text(0.0039017770718303545, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 2.775'),
#  Text(0.004036321108790022, 0.5441176470588235, 'AveRooms <= 3.7\nsquared_error = 0.024\nsamples = 5\nvalue = 3.303'),
#  Text(0.0039017770718303545, 0.5147058823529411, 'HouseAge <= 32.0\nsquared_error = 0.009\nsamples = 3\nvalue = 3.194'),
#  Text(0.003834505053350521, 0.4852941176470588, 'Latitude <= 34.035\nsquared_error = 0.0\nsamples = 2\nvalue = 3.262'),
#  Text(0.003767233034870687, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.273'),
#  Text(0.0039017770718303545, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.25'),
#  Text(0.003969049090310189, 0.4852941176470588, 'squared_error = -0.0\nsamples = 1\nvalue = 3.058'),
#  Text(0.004170865145749689, 0.5147058823529411, 'HouseAge <= 35.0\nsquared_error = 0.0\nsamples = 2\nvalue = 3.467'),
#  Text(0.004103593127269856, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 3.478'),
#  Text(0.0042381371642295235, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 3.456'),
#  Text(0.0042381371642295235, 0.6617647058823529, 'Population <= 435.0\nsquared_error = 0.157\nsamples = 6\nvalue = 3.878'),
#  Text(0.004103593127269856, 0.6323529411764706, 'AveBedrms <= 1.002\nsquared_error = 0.004\nsamples = 2\nvalue = 3.438'),
#  Text(0.004036321108790022, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 3.375'),
#  Text(0.004170865145749689, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.004372681201189191, 0.6323529411764706, 'Longitude <= -118.455\nsquared_error = 0.089\nsamples = 4\nvalue = 4.098'),
#  Text(0.004305409182709357, 0.6029411764705882, 'Population <= 875.0\nsquared_error = 0.018\nsamples = 3\nvalue = 4.256'),
#  Text(0.0042381371642295235, 0.5735294117647058, 'HouseAge <= 45.5\nsquared_error = 0.0\nsamples = 2\nvalue = 4.162'),
#  Text(0.004170865145749689, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 4.182'),
#  Text(0.004305409182709357, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 4.143'),
#  Text(0.004372681201189191, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 4.444'),
#  Text(0.004439953219669024, 0.6029411764705882, 'squared_error = -0.0\nsamples = 1\nvalue = 3.622'),
#  Text(0.005045401385987527, 0.6911764705882353, 'AveOccup <= 1.648\nsquared_error = 0.554\nsamples = 22\nvalue = 4.074'),
#  Text(0.004776313312068192, 0.6617647058823529, 'Longitude <= -118.495\nsquared_error = 0.273\nsamples = 8\nvalue = 4.547'),
#  Text(0.004641769275108526, 0.6323529411764706, 'AveRooms <= 3.294\nsquared_error = 0.141\nsamples = 2\nvalue = 3.875'),
#  Text(0.004574497256628692, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 4.25'),
#  Text(0.004709041293588359, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 3.5'),
#  Text(0.00491085734902786, 0.6323529411764706, 'MedInc <= 3.053\nsquared_error = 0.117\nsamples = 6\nvalue = 4.771'),
#  Text(0.0048435853305480265, 0.6029411764705882, 'MedInc <= 2.093\nsquared_error = 0.04\nsamples = 5\nvalue = 4.9'),
#  Text(0.004776313312068192, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 4.5'),
#  Text(0.00491085734902786, 0.5735294117647058, 'squared_error = -0.0\nsamples = 4\nvalue = 5.0'),
#  Text(0.004978129367507694, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 4.125'),
#  Text(0.005314489459906862, 0.6617647058823529, 'MedInc <= 2.398\nsquared_error = 0.514\nsamples = 14\nvalue = 3.804'),
#  Text(0.005179945422947195, 0.6323529411764706, 'AveOccup <= 2.136\nsquared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.005112673404467361, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.005247217441427029, 0.6029411764705882, 'squared_error = -0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.0054490334968665295, 0.6323529411764706, 'Longitude <= -118.485\nsquared_error = 0.321\nsamples = 12\nvalue = 3.605'),
#  Text(0.005381761478386696, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 4.75'),
#  Text(0.005516305515346364, 0.6029411764705882, 'Latitude <= 34.035\nsquared_error = 0.22\nsamples = 11\nvalue = 3.5'),
#  Text(0.005247217441427029, 0.5735294117647058, 'HouseAge <= 29.5\nsquared_error = 0.105\nsamples = 7\nvalue = 3.215'),
#  Text(0.005112673404467361, 0.5441176470588235, 'Latitude <= 34.025\nsquared_error = 0.02\nsamples = 5\nvalue = 3.039'),
#  Text(0.005045401385987527, 0.5147058823529411, 'AveBedrms <= 1.084\nsquared_error = 0.007\nsamples = 4\nvalue = 2.98'),
#  Text(0.004978129367507694, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 3.109'),
#  Text(0.005112673404467361, 0.4852941176470588, 'HouseAge <= 27.0\nsquared_error = 0.003\nsamples = 3\nvalue = 2.938'),
#  Text(0.005045401385987527, 0.45588235294117646, 'MedInc <= 2.909\nsquared_error = 0.001\nsamples = 2\nvalue = 2.969'),
#  Text(0.004978129367507694, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 2.938'),
#  Text(0.005112673404467361, 0.4264705882352941, 'squared_error = -0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.005179945422947195, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 2.875'),
#  Text(0.005179945422947195, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 3.273'),
#  Text(0.005381761478386696, 0.5441176470588235, 'AveOccup <= 2.044\nsquared_error = 0.048\nsamples = 2\nvalue = 3.657'),
#  Text(0.005314489459906862, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 3.875'),
#  Text(0.0054490334968665295, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 3.438'),
#  Text(0.0057853935892656985, 0.5735294117647058, 'Longitude <= -118.455\nsquared_error = 0.03\nsamples = 4\nvalue = 3.999'),
#  Text(0.005650849552306031, 0.5441176470588235, 'HouseAge <= 21.0\nsquared_error = 0.003\nsamples = 2\nvalue = 4.154'),
#  Text(0.005583577533826197, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 4.208'),
#  Text(0.005718121570785864, 0.5147058823529411, 'squared_error = -0.0\nsamples = 1\nvalue = 4.1'),
#  Text(0.005919937626225366, 0.5441176470588235, 'HouseAge <= 23.5\nsquared_error = 0.009\nsamples = 2\nvalue = 3.844'),
#  Text(0.005852665607745532, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 3.938'),
#  Text(0.005987209644705199, 0.5147058823529411, 'squared_error = -0.0\nsamples = 1\nvalue = 3.75'),
#  Text(0.009421367353704054, 0.7205882352941176, 'Latitude <= 34.045\nsquared_error = 0.883\nsamples = 101\nvalue = 2.535'),
#  Text(0.007803554143660709, 0.6911764705882353, 'Latitude <= 33.925\nsquared_error = 0.261\nsamples = 36\nvalue = 2.001'),
#  Text(0.007088788947312476, 0.6617647058823529, 'HouseAge <= 41.5\nsquared_error = 0.203\nsamples = 19\nvalue = 2.251'),
#  Text(0.0067103838433634115, 0.6323529411764706, 'MedInc <= 2.634\nsquared_error = 0.085\nsamples = 15\nvalue = 2.131'),
#  Text(0.006289933727864451, 0.6029411764705882, 'AveOccup <= 1.998\nsquared_error = 0.046\nsamples = 6\nvalue = 1.923'),
#  Text(0.006121753681664867, 0.5735294117647058, 'Longitude <= -118.27\nsquared_error = 0.062\nsamples = 2\nvalue = 2.125'),
#  Text(0.006054481663185033, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 2.375'),
#  Text(0.006189025700144701, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 1.875'),
#  Text(0.006458113774064036, 0.5735294117647058, 'HouseAge <= 23.0\nsquared_error = 0.007\nsamples = 4\nvalue = 1.822'),
#  Text(0.006323569737104368, 0.5441176470588235, 'MedInc <= 2.147\nsquared_error = 0.001\nsamples = 2\nvalue = 1.901'),
#  Text(0.006256297718624534, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.875'),
#  Text(0.0063908417555842015, 0.5147058823529411, 'squared_error = -0.0\nsamples = 1\nvalue = 1.927'),
#  Text(0.006592657811023703, 0.5441176470588235, 'AveRooms <= 3.88\nsquared_error = 0.001\nsamples = 2\nvalue = 1.744'),
#  Text(0.006525385792543869, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.775'),
#  Text(0.006659929829503536, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.713'),
#  Text(0.007130833958862372, 0.6029411764705882, 'AveOccup <= 2.427\nsquared_error = 0.063\nsamples = 9\nvalue = 2.269'),
#  Text(0.007063561940382539, 0.5735294117647058, 'AveOccup <= 1.978\nsquared_error = 0.041\nsamples = 8\nvalue = 2.212'),
#  Text(0.006861745884943038, 0.5441176470588235, 'MedInc <= 2.788\nsquared_error = 0.018\nsamples = 2\nvalue = 2.472'),
#  Text(0.006794473866463204, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.338'),
#  Text(0.006929017903422871, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.605'),
#  Text(0.007265377995822039, 0.5441176470588235, 'AveOccup <= 2.235\nsquared_error = 0.019\nsamples = 6\nvalue = 2.125'),
#  Text(0.007063561940382539, 0.5147058823529411, 'AveRooms <= 3.489\nsquared_error = 0.005\nsamples = 3\nvalue = 2.021'),
#  Text(0.006996289921902705, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 1.923'),
#  Text(0.007130833958862372, 0.4852941176470588, 'AveOccup <= 2.011\nsquared_error = 0.0\nsamples = 2\nvalue = 2.069'),
#  Text(0.007063561940382539, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 2.05'),
#  Text(0.007198105977342206, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 2.089'),
#  Text(0.007467194051261541, 0.5147058823529411, 'MedInc <= 2.873\nsquared_error = 0.012\nsamples = 3\nvalue = 2.229'),
#  Text(0.007399922032781707, 0.4852941176470588, 'HouseAge <= 28.0\nsquared_error = 0.0\nsamples = 2\nvalue = 2.305'),
#  Text(0.0073326500143018735, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 2.293'),
#  Text(0.007467194051261541, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 2.317'),
#  Text(0.007534466069741374, 0.4852941176470588, 'squared_error = -0.0\nsamples = 1\nvalue = 2.078'),
#  Text(0.007198105977342206, 0.5735294117647058, 'squared_error = -0.0\nsamples = 1\nvalue = 2.728'),
#  Text(0.007467194051261541, 0.6323529411764706, 'AveOccup <= 2.374\nsquared_error = 0.388\nsamples = 4\nvalue = 2.704'),
#  Text(0.007399922032781707, 0.6029411764705882, 'AveRooms <= 4.055\nsquared_error = 0.021\nsamples = 3\nvalue = 2.351'),
#  Text(0.0073326500143018735, 0.5735294117647058, 'squared_error = 0.0\nsamples = 2\nvalue = 2.25'),
#  Text(0.007467194051261541, 0.5735294117647058, 'squared_error = -0.0\nsamples = 1\nvalue = 2.554'),
#  Text(0.007534466069741374, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 3.761'),
#  Text(0.008518319340008943, 0.6617647058823529, 'HouseAge <= 46.0\nsquared_error = 0.176\nsamples = 17\nvalue = 1.721'),
#  Text(0.008089460222200003, 0.6323529411764706, 'AveRooms <= 3.291\nsquared_error = 0.123\nsamples = 13\nvalue = 1.867'),
#  Text(0.007736282125180876, 0.6029411764705882, 'Longitude <= -118.355\nsquared_error = 0.006\nsamples = 5\nvalue = 1.605'),
#  Text(0.007669010106701042, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 1.469'),
#  Text(0.007803554143660709, 0.5735294117647058, 'HouseAge <= 21.5\nsquared_error = 0.002\nsamples = 4\nvalue = 1.639'),
#  Text(0.007669010106701042, 0.5441176470588235, 'AveBedrms <= 1.115\nsquared_error = 0.001\nsamples = 2\nvalue = 1.6'),
#  Text(0.007601738088221208, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.575'),
#  Text(0.007736282125180876, 0.5147058823529411, 'squared_error = -0.0\nsamples = 1\nvalue = 1.625'),
#  Text(0.007938098180620377, 0.5441176470588235, 'MedInc <= 1.211\nsquared_error = 0.0\nsamples = 2\nvalue = 1.678'),
#  Text(0.007870826162140543, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.688'),
#  Text(0.00800537019910021, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.667'),
#  Text(0.00844263831921913, 0.6029411764705882, 'AveRooms <= 3.623\nsquared_error = 0.126\nsamples = 8\nvalue = 2.032'),
#  Text(0.008274458273019545, 0.5735294117647058, 'Population <= 1505.0\nsquared_error = 0.031\nsamples = 3\nvalue = 2.453'),
#  Text(0.008207186254539712, 0.5441176470588235, 'MedInc <= 2.257\nsquared_error = 0.011\nsamples = 2\nvalue = 2.562'),
#  Text(0.008139914236059878, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.667'),
#  Text(0.008274458273019545, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.458'),
#  Text(0.008341730291499379, 0.5441176470588235, 'squared_error = -0.0\nsamples = 1\nvalue = 2.233'),
#  Text(0.008610818365418714, 0.5735294117647058, 'AveRooms <= 3.838\nsquared_error = 0.012\nsamples = 5\nvalue = 1.779'),
#  Text(0.008476274328459047, 0.5441176470588235, 'AveOccup <= 2.037\nsquared_error = 0.002\nsamples = 2\nvalue = 1.657'),
#  Text(0.008409002309979213, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.705'),
#  Text(0.00854354634693888, 0.5147058823529411, 'squared_error = -0.0\nsamples = 1\nvalue = 1.609'),
#  Text(0.008745362402378382, 0.5441176470588235, 'Longitude <= -118.365\nsquared_error = 0.002\nsamples = 3\nvalue = 1.86'),
#  Text(0.008678090383898548, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.798'),
#  Text(0.008812634420858214, 0.5147058823529411, 'AveBedrms <= 1.026\nsquared_error = 0.0\nsamples = 2\nvalue = 1.891'),
#  Text(0.008745362402378382, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 1.897'),
#  Text(0.008879906439338048, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 1.885'),
#  Text(0.008947178457817883, 0.6323529411764706, 'MedInc <= 2.087\nsquared_error = 0.052\nsamples = 4\nvalue = 1.244'),
#  Text(0.008812634420858214, 0.6029411764705882, 'HouseAge <= 50.0\nsquared_error = 0.02\nsamples = 2\nvalue = 1.047'),
#  Text(0.008745362402378382, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 1.188'),
#  Text(0.008879906439338048, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 0.906'),
#  Text(0.00908172249477755, 0.6029411764705882, 'AveBedrms <= 0.925\nsquared_error = 0.006\nsamples = 2\nvalue = 1.441'),
#  Text(0.009014450476297717, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 1.516'),
#  Text(0.009148994513257383, 0.5735294117647058, 'squared_error = -0.0\nsamples = 1\nvalue = 1.366'),
#  Text(0.011039180563747399, 0.6911764705882353, 'Longitude <= -118.305\nsquared_error = 0.982\nsamples = 65\nvalue = 2.831'),
#  Text(0.010238485875044065, 0.6617647058823529, 'Latitude <= 34.075\nsquared_error = 0.868\nsamples = 41\nvalue = 3.198'),
#  Text(0.00950217261027651, 0.6323529411764706, 'AveRooms <= 3.525\nsquared_error = 0.467\nsamples = 8\nvalue = 4.083'),
#  Text(0.009367628573316843, 0.6029411764705882, 'MedInc <= 2.211\nsquared_error = 0.158\nsamples = 5\nvalue = 4.545'),
#  Text(0.009300356554837009, 0.5735294117647058, 'HouseAge <= 35.0\nsquared_error = 0.033\nsamples = 3\nvalue = 4.242'),
#  Text(0.009233084536357175, 0.5441176470588235, 'HouseAge <= 32.0\nsquared_error = 0.0\nsamples = 2\nvalue = 4.112'),
#  Text(0.009165812517877342, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 4.125'),
#  Text(0.009300356554837009, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 4.1'),
#  Text(0.009367628573316843, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 4.5'),
#  Text(0.009434900591796677, 0.5735294117647058, 'squared_error = -0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.009636716647236178, 0.6029411764705882, 'Population <= 1096.5\nsquared_error = 0.034\nsamples = 3\nvalue = 3.313'),
#  Text(0.009569444628756344, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.552'),
#  Text(0.009703988665716012, 0.5735294117647058, 'Latitude <= 34.055\nsquared_error = 0.009\nsamples = 2\nvalue = 3.194'),
#  Text(0.009636716647236178, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 3.288'),
#  Text(0.009771260684195844, 0.5441176470588235, 'squared_error = -0.0\nsamples = 1\nvalue = 3.1'),
#  Text(0.01097479913981162, 0.6323529411764706, 'AveRooms <= 3.773\nsquared_error = 0.73\nsamples = 33\nvalue = 2.983'),
#  Text(0.010715171193491012, 0.6029411764705882, 'Latitude <= 34.105\nsquared_error = 0.456\nsamples = 26\nvalue = 2.788'),
#  Text(0.010397731356289297, 0.5735294117647058, 'AveBedrms <= 1.177\nsquared_error = 0.363\nsamples = 24\nvalue = 2.695'),
#  Text(0.009964667737325367, 0.5441176470588235, 'AveBedrms <= 1.151\nsquared_error = 0.358\nsamples = 21\nvalue = 2.778'),
#  Text(0.009434900591796677, 0.5147058823529411, 'AveRooms <= 3.199\nsquared_error = 0.211\nsamples = 17\nvalue = 2.632'),
#  Text(0.009014450476297717, 0.4852941176470588, 'HouseAge <= 29.5\nsquared_error = 0.055\nsamples = 6\nvalue = 2.115'),
#  Text(0.008879906439338048, 0.45588235294117646, 'AveRooms <= 2.877\nsquared_error = 0.004\nsamples = 2\nvalue = 2.438'),
#  Text(0.008812634420858214, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 2.5'),
#  Text(0.008947178457817883, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 2.375'),
#  Text(0.009148994513257383, 0.45588235294117646, 'Latitude <= 34.095\nsquared_error = 0.003\nsamples = 4\nvalue = 1.953'),
#  Text(0.00908172249477755, 0.4264705882352941, 'squared_error = 0.0\nsamples = 2\nvalue = 2.0'),
#  Text(0.009216266531737217, 0.4264705882352941, 'HouseAge <= 36.5\nsquared_error = 0.001\nsamples = 2\nvalue = 1.906'),
#  Text(0.009148994513257383, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.875'),
#  Text(0.009283538550217052, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.938'),
#  Text(0.009855350707295638, 0.4852941176470588, 'AveRooms <= 3.525\nsquared_error = 0.07\nsamples = 11\nvalue = 2.914'),
#  Text(0.009619898642616219, 0.45588235294117646, 'AveOccup <= 1.97\nsquared_error = 0.054\nsamples = 6\nvalue = 2.767'),
#  Text(0.009552626624136385, 0.4264705882352941, 'MedInc <= 1.913\nsquared_error = 0.025\nsamples = 5\nvalue = 2.849'),
#  Text(0.009418082587176718, 0.39705882352941174, 'AveRooms <= 3.357\nsquared_error = 0.014\nsamples = 2\nvalue = 3.007'),
#  Text(0.009350810568696884, 0.36764705882352944, 'squared_error = 0.0\nsamples = 1\nvalue = 2.889'),
#  Text(0.009485354605656552, 0.36764705882352944, 'squared_error = 0.0\nsamples = 1\nvalue = 3.125'),
#  Text(0.009687170661096053, 0.39705882352941174, 'MedInc <= 2.324\nsquared_error = 0.005\nsamples = 3\nvalue = 2.743'),
#  Text(0.009619898642616219, 0.36764705882352944, 'squared_error = 0.0\nsamples = 1\nvalue = 2.833'),
#  Text(0.009754442679575887, 0.36764705882352944, 'Longitude <= -118.365\nsquared_error = 0.001\nsamples = 2\nvalue = 2.698'),
#  Text(0.009687170661096053, 0.3382352941176471, 'squared_error = 0.0\nsamples = 1\nvalue = 2.729'),
#  Text(0.00982171469805572, 0.3382352941176471, 'squared_error = 0.0\nsamples = 1\nvalue = 2.667'),
#  Text(0.009687170661096053, 0.4264705882352941, 'squared_error = -0.0\nsamples = 1\nvalue = 2.361'),
#  Text(0.010090802771975054, 0.45588235294117646, 'AveBedrms <= 1.113\nsquared_error = 0.033\nsamples = 5\nvalue = 3.091'),
#  Text(0.010023530753495222, 0.4264705882352941, 'Latitude <= 34.085\nsquared_error = 0.016\nsamples = 4\nvalue = 3.162'),
#  Text(0.009956258735015388, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 3.353'),
#  Text(0.010090802771975054, 0.39705882352941174, 'Population <= 2070.5\nsquared_error = 0.005\nsamples = 3\nvalue = 3.098'),
#  Text(0.010023530753495222, 0.36764705882352944, 'Population <= 1000.5\nsquared_error = 0.0\nsamples = 2\nvalue = 3.147'),
#  Text(0.009956258735015388, 0.3382352941176471, 'squared_error = 0.0\nsamples = 1\nvalue = 3.136'),
#  Text(0.010090802771975054, 0.3382352941176471, 'squared_error = -0.0\nsamples = 1\nvalue = 3.158'),
#  Text(0.010158074790454889, 0.36764705882352944, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.010158074790454889, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 2.806'),
#  Text(0.010494434882854058, 0.5147058823529411, 'AveOccup <= 2.247\nsquared_error = 0.512\nsamples = 4\nvalue = 3.396'),
#  Text(0.010427162864374223, 0.4852941176470588, 'MedInc <= 1.934\nsquared_error = 0.14\nsamples = 3\nvalue = 3.028'),
#  Text(0.01035989084589439, 0.45588235294117646, 'AveOccup <= 1.971\nsquared_error = 0.002\nsamples = 2\nvalue = 3.292'),
#  Text(0.010292618827414557, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 3.25'),
#  Text(0.010427162864374223, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 3.333'),
#  Text(0.010494434882854058, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 2.5'),
#  Text(0.010561706901333892, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 4.5'),
#  Text(0.010830794975253227, 0.5441176470588235, 'AveBedrms <= 1.209\nsquared_error = 0.011\nsamples = 3\nvalue = 2.117'),
#  Text(0.010763522956773392, 0.5147058823529411, 'MedInc <= 2.17\nsquared_error = 0.003\nsamples = 2\nvalue = 2.05'),
#  Text(0.010696250938293558, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.010830794975253227, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 2.1'),
#  Text(0.010898066993733059, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.25'),
#  Text(0.011032611030692727, 0.5735294117647058, 'MedInc <= 2.639\nsquared_error = 0.228\nsamples = 2\nvalue = 3.906'),
#  Text(0.010965339012212893, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 4.383'),
#  Text(0.011099883049172561, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 3.429'),
#  Text(0.011234427086132228, 0.6029411764705882, 'AveOccup <= 1.587\nsquared_error = 1.078\nsamples = 7\nvalue = 3.709'),
#  Text(0.011167155067652394, 0.5735294117647058, 'squared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.011301699104612062, 0.5735294117647058, 'MedInc <= 2.817\nsquared_error = 0.575\nsamples = 5\nvalue = 3.192'),
#  Text(0.011234427086132228, 0.5441176470588235, 'AveBedrms <= 1.043\nsquared_error = 0.069\nsamples = 4\nvalue = 3.552'),
#  Text(0.011167155067652394, 0.5147058823529411, 'AveOccup <= 1.915\nsquared_error = 0.011\nsamples = 3\nvalue = 3.695'),
#  Text(0.011099883049172561, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 3.833'),
#  Text(0.011234427086132228, 0.4852941176470588, 'AveRooms <= 3.979\nsquared_error = 0.002\nsamples = 2\nvalue = 3.626'),
#  Text(0.011167155067652394, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.581'),
#  Text(0.011301699104612062, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.671'),
#  Text(0.011301699104612062, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 3.125'),
#  Text(0.011368971123091896, 0.5441176470588235, 'squared_error = -0.0\nsamples = 1\nvalue = 1.75'),
#  Text(0.011839875252450732, 0.6617647058823529, 'AveRooms <= 2.027\nsquared_error = 0.553\nsamples = 24\nvalue = 2.204'),
#  Text(0.011436243141571729, 0.6323529411764706, 'AveRooms <= 1.563\nsquared_error = 0.262\nsamples = 4\nvalue = 3.062'),
#  Text(0.011368971123091896, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 2.25'),
#  Text(0.011503515160051563, 0.6029411764705882, 'AveOccup <= 2.342\nsquared_error = 0.056\nsamples = 3\nvalue = 3.333'),
#  Text(0.011436243141571729, 0.5735294117647058, 'squared_error = 0.0\nsamples = 2\nvalue = 3.5'),
#  Text(0.011570787178531397, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.012243507363329733, 0.6323529411764706, 'AveRooms <= 2.688\nsquared_error = 0.434\nsamples = 20\nvalue = 2.032'),
#  Text(0.011772603233970898, 0.6029411764705882, 'AveBedrms <= 1.067\nsquared_error = 0.436\nsamples = 8\nvalue = 1.524'),
#  Text(0.011705331215491064, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 3.0'),
#  Text(0.011839875252450732, 0.5735294117647058, 'AveBedrms <= 1.092\nsquared_error = 0.142\nsamples = 7\nvalue = 1.313'),
#  Text(0.011638059197011231, 0.5441176470588235, 'AveRooms <= 2.104\nsquared_error = 0.084\nsamples = 3\nvalue = 1.014'),
#  Text(0.011570787178531397, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.417'),
#  Text(0.011705331215491064, 0.5147058823529411, 'Longitude <= -118.27\nsquared_error = 0.004\nsamples = 2\nvalue = 0.812'),
#  Text(0.011638059197011231, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 0.75'),
#  Text(0.011772603233970898, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 0.875'),
#  Text(0.012041691307890233, 0.5441176470588235, 'AveRooms <= 2.611\nsquared_error = 0.068\nsamples = 4\nvalue = 1.538'),
#  Text(0.011974419289410398, 0.5147058823529411, 'AveRooms <= 2.302\nsquared_error = 0.015\nsamples = 3\nvalue = 1.675'),
#  Text(0.011907147270930564, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 1.5'),
#  Text(0.012041691307890233, 0.4852941176470588, 'AveOccup <= 2.371\nsquared_error = 0.0\nsamples = 2\nvalue = 1.762'),
#  Text(0.011974419289410398, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 1.75'),
#  Text(0.012108963326370067, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 1.775'),
#  Text(0.012108963326370067, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.125'),
#  Text(0.012714411492688569, 0.6029411764705882, 'HouseAge <= 41.0\nsquared_error = 0.146\nsamples = 12\nvalue = 2.371'),
#  Text(0.012445323418769234, 0.5735294117647058, 'AveBedrms <= 1.098\nsquared_error = 0.086\nsamples = 7\nvalue = 2.6'),
#  Text(0.012310779381809567, 0.5441176470588235, 'AveOccup <= 2.157\nsquared_error = 0.104\nsamples = 3\nvalue = 2.378'),
#  Text(0.012243507363329733, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.833'),
#  Text(0.012378051400289402, 0.5147058823529411, 'MedInc <= 2.669\nsquared_error = 0.0\nsamples = 2\nvalue = 2.151'),
#  Text(0.012310779381809567, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 2.167'),
#  Text(0.012445323418769234, 0.4852941176470588, 'squared_error = -0.0\nsamples = 1\nvalue = 2.135'),
#  Text(0.012579867455728902, 0.5441176470588235, 'AveRooms <= 3.052\nsquared_error = 0.009\nsamples = 4\nvalue = 2.766'),
#  Text(0.012512595437249068, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 2.906'),
#  Text(0.012647139474208736, 0.5147058823529411, 'AveBedrms <= 1.105\nsquared_error = 0.003\nsamples = 3\nvalue = 2.72'),
#  Text(0.012579867455728902, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 2.643'),
#  Text(0.012714411492688569, 0.4852941176470588, 'Population <= 1010.0\nsquared_error = 0.0\nsamples = 2\nvalue = 2.758'),
#  Text(0.012647139474208736, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 2.766'),
#  Text(0.012781683511168403, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 2.75'),
#  Text(0.012983499566607904, 0.5735294117647058, 'Population <= 625.0\nsquared_error = 0.055\nsamples = 5\nvalue = 2.051'),
#  Text(0.012916227548128071, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 1.643'),
#  Text(0.013050771585087738, 0.5441176470588235, 'AveBedrms <= 1.063\nsquared_error = 0.016\nsamples = 4\nvalue = 2.153'),
#  Text(0.012916227548128071, 0.5147058823529411, 'HouseAge <= 48.0\nsquared_error = 0.0\nsamples = 2\nvalue = 2.269'),
#  Text(0.012848955529648237, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 2.25'),
#  Text(0.012983499566607904, 0.4852941176470588, 'squared_error = -0.0\nsamples = 1\nvalue = 2.288'),
#  Text(0.013185315622047406, 0.5147058823529411, 'Latitude <= 34.095\nsquared_error = 0.005\nsamples = 2\nvalue = 2.037'),
#  Text(0.013118043603567572, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 1.965'),
#  Text(0.013252587640527239, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 2.109'),
#  Text(0.017944047221278035, 0.75, 'AveOccup <= 2.121\nsquared_error = 0.675\nsamples = 226\nvalue = 2.049'),
#  Text(0.013697525690487487, 0.7205882352941176, 'Population <= 31.0\nsquared_error = 0.814\nsamples = 122\nvalue = 2.262'),
#  Text(0.013630253672007653, 0.6911764705882353, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.013764797708967321, 0.6911764705882353, 'MedInc <= 0.812\nsquared_error = 0.758\nsamples = 121\nvalue = 2.239'),
#  Text(0.013050771585087738, 0.6617647058823529, 'AveRooms <= 2.66\nsquared_error = 0.267\nsamples = 5\nvalue = 1.214'),
#  Text(0.012916227548128071, 0.6323529411764706, 'Longitude <= -122.08\nsquared_error = 0.035\nsamples = 2\nvalue = 1.812'),
#  Text(0.012848955529648237, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 1.625'),
#  Text(0.012983499566607904, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 2.0'),
#  Text(0.013185315622047406, 0.6323529411764706, 'AveOccup <= 1.418\nsquared_error = 0.024\nsamples = 3\nvalue = 0.816'),
#  Text(0.013118043603567572, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 0.6'),
#  Text(0.013252587640527239, 0.6029411764705882, 'HouseAge <= 36.0\nsquared_error = 0.001\nsamples = 2\nvalue = 0.924'),
#  Text(0.013185315622047406, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 0.895'),
#  Text(0.013319859659007073, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 0.952'),
#  Text(0.014478823832846903, 0.6617647058823529, 'AveOccup <= 1.435\nsquared_error = 0.732\nsamples = 116\nvalue = 2.283'),
#  Text(0.013588947732926408, 0.6323529411764706, 'Population <= 432.0\nsquared_error = 1.901\nsamples = 4\nvalue = 3.656'),
#  Text(0.013521675714446573, 0.6029411764705882, 'AveRooms <= 3.853\nsquared_error = 1.125\nsamples = 3\nvalue = 4.25'),
#  Text(0.013454403695966741, 0.5735294117647058, 'Latitude <= 35.415\nsquared_error = 0.0\nsamples = 2\nvalue = 5.0'),
#  Text(0.013387131677486907, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.013521675714446573, 0.5441176470588235, 'squared_error = -0.0\nsamples = 1\nvalue = 5.0'),
#  Text(0.013588947732926408, 0.5735294117647058, 'squared_error = 0.0\nsamples = 1\nvalue = 2.75'),
#  Text(0.013656219751406242, 0.6029411764705882, 'squared_error = 0.0\nsamples = 1\nvalue = 1.875'),
#  Text(0.0153686999327674, 0.6323529411764706, 'HouseAge <= 15.5\nsquared_error = 0.621\nsamples = 112\nvalue = 2.234'),
#  Text(0.014026215853045327, 0.6029411764705882, 'AveRooms <= 3.781\nsquared_error = 0.676\nsamples = 14\nvalue = 1.765'),
#  Text(0.013790763788365908, 0.5735294117647058, 'Population <= 525.0\nsquared_error = 0.527\nsamples = 9\nvalue = 2.157'),
#  Text(0.013656219751406242, 0.5441176470588235, 'MedInc <= 1.777\nsquared_error = 0.191\nsamples = 2\nvalue = 1.038'),
#  Text(0.013588947732926408, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 1.475'),
#  Text(0.013723491769886076, 0.5147058823529411, 'squared_error = -0.0\nsamples = 1\nvalue = 0.6'),
#  Text(0.013925307825325577, 0.5441176470588235, 'Population <= 655.5\nsquared_error = 0.163\nsamples = 7\nvalue = 2.477'),
#  Text(0.013858035806845742, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 3.25'),
#  Text(0.01399257984380541, 0.5147058823529411, 'AveBedrms <= 0.961\nsquared_error = 0.074\nsamples = 6\nvalue = 2.348'),
#  Text(0.013925307825325577, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 2.841'),
#  Text(0.014059851862285243, 0.4852941176470588, 'Latitude <= 37.79\nsquared_error = 0.03\nsamples = 5\nvalue = 2.25'),
#  Text(0.01399257984380541, 0.45588235294117646, 'AveRooms <= 3.586\nsquared_error = 0.011\nsamples = 4\nvalue = 2.323'),
#  Text(0.013925307825325577, 0.4264705882352941, 'Latitude <= 37.495\nsquared_error = 0.001\nsamples = 3\nvalue = 2.263'),
#  Text(0.013858035806845742, 0.39705882352941174, 'AveOccup <= 1.897\nsquared_error = 0.0\nsamples = 2\nvalue = 2.238'),
#  Text(0.013790763788365908, 0.36764705882352944, 'squared_error = 0.0\nsamples = 1\nvalue = 2.227'),
#  Text(0.013925307825325577, 0.36764705882352944, 'squared_error = -0.0\nsamples = 1\nvalue = 2.25'),
#  Text(0.01399257984380541, 0.39705882352941174, 'squared_error = -0.0\nsamples = 1\nvalue = 2.313'),
#  Text(0.014059851862285243, 0.4264705882352941, 'squared_error = 0.0\nsamples = 1\nvalue = 2.5'),
#  Text(0.014127123880765077, 0.45588235294117646, 'squared_error = -0.0\nsamples = 1\nvalue = 1.958'),
#  Text(0.014261667917724744, 0.5735294117647058, 'AveOccup <= 2.06\nsquared_error = 0.169\nsamples = 5\nvalue = 1.06'),
#  Text(0.014194395899244911, 0.5441176470588235, 'Population <= 673.5\nsquared_error = 0.062\nsamples = 4\nvalue = 0.888'),
#  Text(0.014127123880765077, 0.5147058823529411, 'squared_error = 0.0\nsamples = 2\nvalue = 1.125'),
#  Text(0.014261667917724744, 0.5147058823529411, 'Population <= 1582.5\nsquared_error = 0.012\nsamples = 2\nvalue = 0.651'),
#  Text(0.014194395899244911, 0.4852941176470588, 'squared_error = 0.0\nsamples = 1\nvalue = 0.542'),
#  Text(0.014328939936204578, 0.4852941176470588, 'squared_error = -0.0\nsamples = 1\nvalue = 0.759'),
#  Text(0.014328939936204578, 0.5441176470588235, 'squared_error = 0.0\nsamples = 1\nvalue = 1.75'),
#  Text(0.01671118401248947, 0.6029411764705882, 'MedInc <= 2.065\nsquared_error = 0.577\nsamples = 98\nvalue = 2.301'),
#  Text(0.015586085781546471, 0.5735294117647058, 'Population <= 5536.5\nsquared_error = 0.614\nsamples = 24\nvalue = 1.881'),
#  Text(0.015518813763066637, 0.5441176470588235, 'Latitude <= 37.845\nsquared_error = 0.483\nsamples = 23\nvalue = 1.8'),
#  Text(0.014892343090973186, 0.5147058823529411, 'Latitude <= 35.33\nsquared_error = 0.404\nsamples = 17\nvalue = 1.6'),
#  Text(0.014463483973164246, 0.4852941176470588, 'AveRooms <= 3.956\nsquared_error = 0.263\nsamples = 5\nvalue = 2.282'),
#  Text(0.014396211954684412, 0.45588235294117646, 'Population <= 717.0\nsquared_error = 0.022\nsamples = 4\nvalue = 2.034'),
#  Text(0.014261667917724744, 0.4264705882352941, 'MedInc <= 1.794\nsquared_error = 0.0\nsamples = 2\nvalue = 1.896'),
#  Text(0.014194395899244911, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.875'),
#  Text(0.014328939936204578, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.917'),
#  Text(0.014530755991644079, 0.4264705882352941, 'HouseAge <= 28.0\nsquared_error = 0.006\nsamples = 2\nvalue = 2.173'),
#  Text(0.014463483973164246, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 2.25'),
#  Text(0.014598028010123913, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 2.096'),
#  Text(0.014530755991644079, 0.45588235294117646, 'squared_error = 0.0\nsamples = 1\nvalue = 3.273'),
#  Text(0.015321202208782126, 0.4852941176470588, 'AveRooms <= 3.779\nsquared_error = 0.188\nsamples = 12\nvalue = 1.316'),
#  Text(0.015035296130242832, 0.45588235294117646, 'HouseAge <= 32.5\nsquared_error = 0.047\nsamples = 7\nvalue = 1.626'),
#  Text(0.014867116084043248, 0.4264705882352941, 'AveBedrms <= 1.039\nsquared_error = 0.015\nsamples = 4\nvalue = 1.789'),
#  Text(0.014732572047083581, 0.39705882352941174, 'Longitude <= -122.275\nsquared_error = 0.002\nsamples = 2\nvalue = 1.672'),
# ...
#  Text(0.03322186587615038, 0.6029411764705882, 'Latitude <= 34.145\nsquared_error = 0.319\nsamples = 54\nvalue = 1.721'),
#  Text(0.03253863443846456, 0.5735294117647058, 'AveOccup <= 2.504\nsquared_error = 0.094\nsamples = 48\nvalue = 1.653'),
#  Text(0.03247136241998473, 0.5441176470588235, 'AveOccup <= 1.385\nsquared_error = 0.069\nsamples = 47\nvalue = 1.677'),
#  Text(0.032404090401504895, 0.5147058823529411, 'squared_error = 0.0\nsamples = 1\nvalue = 0.675'),
#  Text(0.03253863443846456, 0.5147058823529411, 'MedInc <= 1.758\nsquared_error = 0.048\nsamples = 46\nvalue = 1.699'),
#  Text(0.03157580367397194, 0.4852941176470588, 'MedInc <= 1.134\nsquared_error = 0.042\nsamples = 14\nvalue = 1.529'),
#  Text(0.03130671560005261, 0.45588235294117646, 'Latitude <= 33.865\nsquared_error = 0.012\nsamples = 4\nvalue = 1.712'),
#  Text(0.031172171563092942, 0.4264705882352941, 'Population <= 824.5\nsquared_error = 0.004\nsamples = 2\nvalue = 1.812'),
#  Text(0.031104899544613106, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.75'),
#  Text(0.031239443581572775, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.875'),
#  Text(0.031441259637012275, 0.4264705882352941, 'HouseAge <= 33.0\nsquared_error = 0.0\nsamples = 2\nvalue = 1.612'),
#  Text(0.03137398761853244, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.599'),
#  Text(0.03150853165549211, 0.39705882352941174, 'squared_error = -0.0\nsamples = 1\nvalue = 1.625'),
#  Text(0.03184489174789128, 0.45588235294117646, 'AveBedrms <= 1.075\nsquared_error = 0.035\nsamples = 10\nvalue = 1.456'),
#  Text(0.03171034771093161, 0.4264705882352941, 'Longitude <= -118.145\nsquared_error = 0.011\nsamples = 2\nvalue = 1.729'),
#  Text(0.031643075692451776, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.625'),
#  Text(0.03177761972941145, 0.39705882352941174, 'squared_error = -0.0\nsamples = 1\nvalue = 1.833'),
#  Text(0.03197943578485095, 0.4264705882352941, 'MedInc <= 1.19\nsquared_error = 0.018\nsamples = 8\nvalue = 1.388'),
#  Text(0.03191216376637111, 0.39705882352941174, 'squared_error = 0.0\nsamples = 1\nvalue = 1.125'),
#  Text(0.03204670780333078, 0.39705882352941174, 'HouseAge <= 42.5\nsquared_error = 0.009\nsamples = 7\nvalue = 1.426'),
#  Text(0.03197943578485095, 0.36764705882352944, 'MedInc <= 1.494\nsquared_error = 0.003\nsamples = 6\nvalue = 1.392'),
#  Text(0.03191216376637111, 0.3382352941176471, 'AveRooms <= 2.807\nsquared_error = 0.001\nsamples = 4\nvalue = 1.36'),
#  Text(0.03184489174789128, 0.3088235294117647, 'squared_error = 0.0\nsamples = 1\nvalue = 1.313'),
#  Text(0.03197943578485095, 0.3088235294117647, 'squared_error = 0.0\nsamples = 3\nvalue = 1.375'),
#  Text(0.03204670780333078, 0.3382352941176471, 'squared_error = -0.0\nsamples = 2\nvalue = 1.458'),
#  Text(0.03211397982181061, 0.36764705882352944, 'squared_error = 0.0\nsamples = 1\nvalue = 1.625'),
#  Text(0.03350146520295718, 0.4852941176470588, 'AveOccup <= 2.397\nsquared_error = 0.033\nsamples = 32\nvalue = 1.773'),
#  Text(0.03320715012210791, 0.45588235294117646, 'AveOccup <= 2.372\nsquared_error = 0.027\nsamples = 27\nvalue = 1.733'),
#  ...]
# Error in callback <function flush_figures at 0x7efc25f86e50> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# /usr/local/lib/python3.8/dist-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-2> in __call__(self, obj)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     242
#     243     if 'png' in formats:
# --> 244         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     245     if 'retina' in formats or 'png2x' in formats:
#     246         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /usr/local/lib/python3.8/dist-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     126
#     127     bytes_io = BytesIO()
# --> 128     fig.canvas.print_figure(bytes_io, **kw)
#     129     data = bytes_io.getvalue()
#     130     if fmt == 'svg':
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2317                 # force the figure dpi to 72), so we need to set it again here.
#    2318                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319                     result = print_method(
#    2320                         filename,
#    2321                         facecolor=facecolor,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1646             kwargs.pop(arg)
#    1647
# -> 1648         return func(*args, **kwargs)
#    1649
#    1650     return wrapper
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     413                          else deprecation_addendum,
#     414                 **kwargs)
# --> 415         return func(*inner_args, **inner_kwargs)
#     416
#     417     DECORATORS[wrapper] = decorator
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     538             *metadata*, including the default 'Software' key.
#     539         """
# --> 540         FigureCanvasAgg.draw(self)
#     541         mpl.image.imsave(
#     542             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     434              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435               else nullcontext()):
# --> 436             self.figure.draw(self.renderer)
#     437             # A GUI class may be need to update a window using this draw, so
#     438             # don't forget to call the superclass.
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    2843
#    2844             self.patch.draw(renderer)
# -> 2845             mimage._draw_list_compositing_images(
#    2846                 renderer, self, artists, self.suppressComposite)
#    2847
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3089             renderer.stop_rasterizing()
#    3090
# -> 3091         mimage._draw_list_compositing_images(
#    3092             renderer, self, artists, self.figure.suppressComposite)
#    3093
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130     if not_composite or not has_images:
#     131         for a in artists:
# --> 132             a.draw(renderer)
#     133     else:
#     134         # Composite any adjacent images together
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/text.py in draw(self, renderer)
#    1976             if self.arrow_patch.figure is None and self.figure is not None:
#    1977                 self.arrow_patch.figure = self.figure
# -> 1978             self.arrow_patch.draw(renderer)
#    1979         # Draw text, including FancyBboxPatch, after FancyArrowPatch.
#    1980         # Otherwise, a wedge arrowstyle can land partly on top of the Bbox.
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in draw(self, renderer)
#    4489             # too.
#    4490             self._dpi_cor = renderer.points_to_pixels(1.)
# -> 4491             path, fillable = self._get_path_in_displaycoord()
#    4492
#    4493             if not np.iterable(fillable):
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in _get_path_in_displaycoord(self)
#    4457             posB = self._convert_xy_units(self._posA_posB[1])
#    4458             (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4459             _path = self.get_connectionstyle()(posA, posB,
#    4460                                                patchA=self.patchA,
#    4461                                                patchB=self.patchB,
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in __call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2774             """
#    2775             path = self.connect(posA, posB)
# -> 2776             clipped_path = self._clip(path, patchA, patchB)
#    2777             shrunk_path = self._shrink(clipped_path, shrinkA, shrinkB)
#    2778             return shrunk_path
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in _clip(self, path, patchA, patchB)
#    2729
#    2730                 try:
# -> 2731                     left, right = split_path_inout(path, insideA)
#    2732                 except ValueError:
#    2733                     right = path
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/bezier.py in split_path_inout(path, inside, tolerance, reorder_inout)
#     369
#     370     bp = bezier_path.reshape((-1, 2))
# --> 371     left, right = split_bezier_intersecting_with_closedpath(
#     372         bp, inside, tolerance)
#     373     if len(left) == 2:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/bezier.py in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     332     bezier_point_at_t = bz.point_at_t
#     333
# --> 334     t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     335         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     336
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/bezier.py in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     168         middle_t = 0.5 * (t0 + t1)
#     169         middle = bezier_point_at_t(middle_t)
# --> 170         middle_inside = inside_closedpath(middle)
#     171
#     172         if start_inside ^ middle_inside:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in insideA(xy_display)
#    2726                 def insideA(xy_display):
#    2727                     xy_event = ConnectionStyle._Base.SimpleEvent(xy_display)
# -> 2728                     return patchA.contains(xy_event)[0]
#    2729
#    2730                 try:
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in contains(self, mouseevent, radius)
#     151             return inside, info
#     152         radius = self._process_radius(radius)
# --> 153         codes = self.get_path().codes
#     154         if codes is not None:
#     155             vertices = self.get_path().vertices
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/patches.py in get_path(self)
#    4038         # Call boxstyle with squeezed height.
#    4039         try:
# -> 4040             inspect.signature(boxstyle).bind(x, y, width, height, m_scale)
#    4041         except TypeError:
#    4042             # Don't apply aspect twice.
#
# /usr/lib/python3.8/inspect.py in signature(obj, follow_wrapped)
#    3103 def signature(obj, *, follow_wrapped=True):
#    3104     """Get a signature object for the passed callable."""
# -> 3105     return Signature.from_callable(obj, follow_wrapped=follow_wrapped)
#    3106
#    3107
#
# /usr/lib/python3.8/inspect.py in from_callable(cls, obj, follow_wrapped)
#    2852     def from_callable(cls, obj, *, follow_wrapped=True):
#    2853         """Constructs Signature for the given callable object."""
# -> 2854         return _signature_from_callable(obj, sigcls=cls,
#    2855                                         follow_wrapper_chains=follow_wrapped)
#    2856
#
# /usr/lib/python3.8/inspect.py in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, sigcls)
#    2305                                         skip_bound_arg=skip_bound_arg)
#    2306
# -> 2307     if _signature_is_builtin(obj):
#    2308         return _signature_from_builtin(sigcls, obj,
#    2309                                        skip_bound_arg=skip_bound_arg)
#
# /usr/lib/python3.8/inspect.py in _signature_is_builtin(obj)
#    1841     """
#    1842     return (isbuiltin(obj) or
# -> 1843             ismethoddescriptor(obj) or
#    1844             isinstance(obj, _NonUserDefinedCallables) or
#    1845             # Can't test 'isinstance(type)' here, as it would
#
# /usr/lib/python3.8/inspect.py in ismethoddescriptor(object)
#     106         return False
#     107     tp = type(object)
# --> 108     return hasattr(tp, "__get__") and not hasattr(tp, "__set__")
#     109
#     110 def isdatadescriptor(object):
#
# KeyboardInterrupt:
